# %% [markdown]
# <a href="https://colab.research.google.com/github/vtr257/python/blob/main/C%C3%B3pia_de_Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #aula4

# %%
def tabuada(numero):
   for contador in range(1, 11): # Gera números de 1 a 10
     print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# #aula 5

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
        print("olá, sou seu assistente virtual") nome = input("digite seu-nome") print(f"ola (nome) em que posso ajudar") resposta = input ("voce deseja falr sobre python, javascript ou matematica:"). lower() if resposta="python": print("Ótimo, vamos falar sobre Python!") elif resposta=="matemática": print(f"otimo, (nome), vamos falar sobre javascript") elif resposta=="matemática": print(f"otimo, (nome), vamos falar sobre javascript")


Parece que esta mensagem está em inglês
